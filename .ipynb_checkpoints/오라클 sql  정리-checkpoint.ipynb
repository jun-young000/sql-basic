# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 기본키와 외래키는 매우매우 중요함.~!!!!!!!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
보통은 1NF 나 2NF 에서 끝난다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### VARCHAR2 와 CHAR 의 차이점 인지할것!!
#
# CHAR:고정길이     VARCHAR2:가변길이

# %% [markdown]
# #### CLOB와 BLOB 의 차이점 인지할것!!
# CLOB 은 CHAR이 들어가고 BLOB은 보통 파일업로드 서버를 따로 만들고 경로만 데이터 베이스에 집어넣는경우가 더많다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 기본 테이블 설정 하고 시작
#
# <!-- DROP TABLE DEPT;
# CREATE TABLE DEPT
# (DEPTNO NUMBER(2) CONSTRAINT PK_DEPT PRIMARY KEY,
# DNAME VARCHAR2(14) ,
# LOC VARCHAR2(13) ) ;
#
# INSERT INTO DEPT VALUES
# (10,'ACCOUNTING','NEW YORK');
# INSERT INTO DEPT VALUES (20,'RESEARCH','DALLAS');
# INSERT INTO DEPT VALUES
# (30,'SALES','CHICAGO');
# INSERT INTO DEPT VALUES
# (40,'OPERATIONS','BOSTON');
#
#
# DROP TABLE EMP;
# CREATE TABLE EMP
# (EMPNO NUMBER(4) CONSTRAINT PK_EMP PRIMARY KEY,
# ENAME VARCHAR2(10),
# JOB VARCHAR2(9),
# MGR NUMBER(4),
# HIREDATE DATE,
# SAL NUMBER(7,2),
# COMM NUMBER(7,2),
# DEPTNO NUMBER(2) CONSTRAINT FK_DEPTNO REFERENCES DEPT);
#
# INSERT INTO EMP VALUES
# (7369,'SMITH','CLERK',7902,to_date('17-12-1980','dd-mm-yyyy'),800,NULL,20);
# INSERT INTO EMP VALUES
# (7499,'ALLEN','SALESMAN',7698,to_date('20-2-1981','dd-mm-yyyy'),1600,300,30);
# INSERT INTO EMP VALUES
# (7521,'WARD','SALESMAN',7698,to_date('22-2-1981','dd-mm-yyyy'),1250,500,30);
# INSERT INTO EMP VALUES
# (7566,'JONES','MANAGER',7839,to_date('2-4-1981','dd-mm-yyyy'),2975,NULL,20);
# INSERT INTO EMP VALUES
# (7654,'MARTIN','SALESMAN',7698,to_date('28-9-1981','dd-mm-yyyy'),1250,1400,30);
# INSERT INTO EMP VALUES
# (7698,'BLAKE','MANAGER',7839,to_date('1-5-1981','dd-mm-yyyy'),2850,NULL,30);
# INSERT INTO EMP VALUES
# (7782,'CLARK','MANAGER',7839,to_date('9-6-1981','dd-mm-yyyy'),2450,NULL,10);
# INSERT INTO EMP VALUES
# (7788,'SCOTT','ANALYST',7566,to_date('13-JUL-87')-85,3000,NULL,20);
# INSERT INTO EMP VALUES
# (7839,'KING','PRESIDENT',NULL,to_date('17-11-1981','dd-mm-yyyy'),5000,NULL,10);
# INSERT INTO EMP VALUES
# (7844,'TURNER','SALESMAN',7698,to_date('8-9-1981','dd-mm-yyyy'),1500,0,30);
# INSERT INTO EMP VALUES
# (7876,'ADAMS','CLERK',7788,to_date('13-JUL-87')-51,1100,NULL,20);
# INSERT INTO EMP VALUES
# (7900,'JAMES','CLERK',7698,to_date('3-12-1981','dd-mm-yyyy'),950,NULL,30);
# INSERT INTO EMP VALUES
# (7902,'FORD','ANALYST',7566,to_date('3-12-1981','dd-mm-yyyy'),3000,NULL,20);
# INSERT INTO EMP VALUES
# (7934,'MILLER','CLERK',7782,to_date('23-1-1982','dd-mm-yyyy'),1300,NULL,10);
#
# DROP TABLE BONUS;
# CREATE TABLE BONUS
# (
# ENAME VARCHAR2(10) ,
# JOB VARCHAR2(9) ,
# SAL NUMBER,
# COMM NUMBER
# ) ;
#
# DROP TABLE SALGRADE;
# CREATE TABLE SALGRADE
# ( GRADE NUMBER,
# LOSAL NUMBER,
# HISAL NUMBER );
#
# INSERT INTO SALGRADE VALUES (1,700,1200);
# INSERT INTO SALGRADE VALUES (2,1201,1400);
# INSERT INTO SALGRADE VALUES (3,1401,2000);
# INSERT INTO SALGRADE VALUES (4,2001,3000);
# INSERT INTO SALGRADE VALUES (5,3001,9999);
# COMMIT; -->

# %% [markdown]
# 화면 출력 사이즈 조정
# SET LINESIZE 250;
# SET PAGESIZE 30;

# %% [markdown]
#     사원 테이블(EMP)의 모든 데이터를 출력하자
#     SELECT *
#     FROM EMP;
#
#     사원 테이블에서 사원의 이름(ENAME), 사원번호(EMPNO), 월급(SAL)을 출력하자
#     SELECT ENAME, EMPNO, SAL
#     FROM EMP;
#
#     사원 테이블에서 사원의 이름과 연봉을 출력하자
#
#     SELECT ENAME, SAL*12
#     FROM EMP;
#
#     SELECT ENAME, SAL*12+COMM
#     FROM EMP;
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
#     COMM 값이 정해져 있지 않다...NULL값임..O과 NULL은 다르다
#
#     사원 테이블에서 사원의 이름, 입사일(HIREDATE), 부서번호(DEPTNO)를 출력하자
#
#     SELECT ENAME, HIREDATE, DEPTNO
#     FROM EMP;
#
#     사원 테이블에서 사원의 이름과, 해당 사원의 관리자(MGR)를 출력하자
#
#     SELECT ENAME, MGR
#     FROM EMP;
#
#     부서 테이블(DEPT)의 구조를 보자
#     DESC DEPT;
#
#
#
#     사원 테이블에서 사원의 이름, 월급, 커미션(COMM)을 출력하자
#
#     SELECT ENAME, SAL, COMM
#     FROM EMP;
#
#     사원 테이블의 모든 데이터를 “ㅇㅇ님이 ㅇㅇ에 입사를 하고 ㅇㅇ의 월급을 받습니다” 형식으로 출력하자
#     (하나의 컬럼으로)
#
#     SELECT ENAME || '님이 ' || HIREDATE || '에 입사를 하고 ' || SAL || '의 월급을 받습니다' AS 직원소개
#     FROM EMP;
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     사원 테이블에서 사원번호가 ‘7844’인 사원의 사원번호, 이름, 월급을 출력하자
#
#     SELECT EMPNO, ENAME, SAL
#     FROM EMP
#     WHERE EMPNO = 7844;
#
#
#     사원 테이블에서 ‘SMITH’의 사원번호, 이름, 월급을 출력하자
#
#     SELECT EMPNO, ENAME, SAL
#     FROM EMP
#     WHERE ENAME = 'SMITH';
#
#     사원 테이블에서 입사일이 1980년 12월 17일인 사원의 모든 데이터를 출력하자
#
#     SELECT * FROM EMP WHERE HIREDATE = '1980/12/17';
#     SELECT * FROM EMP WHERE HIREDATE = '80/12/17';
#     SELECT * FROM EMP WHERE HIREDATE = '1980-12-17';
#     SELECT * FROM EMP WHERE HIREDATE = '80-12-17';
#
#     아무거나 다 가능
#
#     사원 테이블에서 1980년부터 1982년 사이에 입사한 사원의 이름과 입사일을 출력하자
#
#     SELECT ENAME, HIREDATE
#     FROM EMP
#     WHERE HIREDATE >= '80/01/01' AND HIREDATE <= '82/12/31';
#
#
#
#     SELECT ENAME, HIREDATE
#     FROM EMP
#     WHERE HIREDATE BETWEEN '80/01/01' AND '82/12/31';
#
#
#     월급이 2000 이하인 사원의 이름과 월급을 출력하자
#
#     SELECT ENAME, SAL
#     FROM EMP
#     WHERE SAL <= 2000;
#
#
#
#     사원번호가 7369, 7499, 7521인 사원들의 이름과 월급을 출력하자
#
#     SELECT ENAME, SAL FROM EMP WHERE
#     EMPNO = 7369 OR EMPNO = 7499 OR EMPNO = 7521;
#
#     SELECT ENAME, SAL
#     FROM EMP
#     WHERE EMPNO IN (7369, 7499, 7521);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1번 방식
#
# 사원 테이블에
# 사원번호 : 1112
# 이름 : KIM
# 월급 : 2500
# 부서 : 30
# 입력하자
#
#
# INSERT INTO EMP(EMPNO, ENAME, SAL, DEPTNO)VALUES(1112, 'KIM', 2500, 30);

# %%
2번 방식


사원 테이블에 
사원번호:1111, 
이름:HONG, 
직업:ENGINEER, 
관리자:없음, 
입사일:오늘 날짜,
월급:3000, 
커미션:없음, 
부서번호:30을 추가
            
                     
            
INSERT INTO EMP VALUES(1111,'HONG','ENGINEER',NULL,SYSDATE,3000,NULL,30);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
UPDATE EMP SET SAL = 3500 WHERE ENAME = 'HONG';

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
사원테이블에서 번호가 1112번인 사원을 삭제하자

DELETE FROM EMP
WHERE EMPNO = 1112;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
VIEW: 읽기 전용>!! 추후 내용 추가

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 시퀀스는 걍 하나씩 증가하는 거라고 생각.결혼식장 부페에 하각들어갈때 직원이 짤깍 짤깍 하면서 하나씩 세는거 생각하면 이해편함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
FALSE 조건 아무거나 하면됨. 그럼 데이터는 출력은 안되고 컬럼만 나옴..즉 구조만 복제되는 상황

# %%
size가 10인 문자형 컬럼 ID와 PW를 가진 TEST 테이블을 생성하자


CREATE TABLE TEST(
  ID VARCHAR2(10),
  PW VARCHAR2(10)
);



사원 테이블(EMP)의 모든 구조와 데이터를 TEST01로 복사하자

CREATE TABLE TEST01 AS SELECT * FROM EMP;

사원 테이블에서 사원의 번호와 이름을 TEST02로 복사하자

CREATE TABLE TEST02 AS SELECT EMPNO, ENAME FROM EMP;

사원 테입르에서 사원의 번호와 이름을 TEST03으로 복사하자 (컬럼명을 M1, M2로 변경하자)
1번
CREATE TABLE TEST03 AS SELECT EMPNO AS M1, ENAME AS M2 FROM EMP;

2번
CREATE TABLE TEST033(M1, M2) AS SELECT EMPNO, ENAME FROM EMP;


사원 테이블의 구조만 TEST04로 복사하자


CREATE TABLE TEST04 AS SELECT * FROM EMP WHERE 1 = 2;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ID 는 NOT NULL 이라고 설정했는데 ID값을 안넣었음..

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 매우중요
#
#
# NOT  NULL 은 무조컨!!!!!!!!!!! 컬럼레벨에서만 만들어진다....테이블레벨에서 안됨!!!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 유일한값!!!
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 입력이 되는이유  잘보면  CONSTRAINT TU02_ID_UN UNIQUE(ID, NAME) 이부분은 ID와 NAME를  컬럼 두개를 하나로 생각해서

# 둘다 같을때에 무결성 제약 조건을 위배함.사실상 AND같은 느낌

# 복합키 개념하고 연계되는 내용


# 코드착각하면  ID, NAME을 현재 따로 따로 유니크 걸었다고 착각함!!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 해당 데이터 전체에서 유일하게 하나만 식별할수 있어야 하는키!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# NULL 값이 있으면 안됨!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 참조가 되는 TABLE_PK01 을 보면 ID=100, NAME=ORACLE만 존재
즉 두번쨰 오류는 참조하려는 테이블에 해당테이블이 없어서
   세번째 오류는 말그래도 NULL값임

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 반드시 참조하려는 TABLE_PK02(ID, NAME)에 값이 있어야 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'Y', 'N' 둘중 하나만 선택하게끔..했었음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 동일한이유

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TRANSACTION 이란 ?  최소한의 작업단위
#
#
# COMMIT를 보내기 전에는 DATABASE에 정보가 넘어가는게 아니다..
# COMMIT 날려야 DATABASE 정보가 변화한다.
# CMOMMIT는 DB에 확정하는 작업이다.
#
#
# 즉 SQLPLUS는 클라이언트
# 예를 종료하면 자동으로 COMMIT 함
#
#
# 롤백은 서버를 백하는거...게임생각해보면..뭐..
# 롤백은 가장 마지막 COMMIT 시점으로 돌아간다
#
#
# 그래서 작업단위를 저장하나 취소하냐 하기 때문에 COMMIT와 ROLLBACK를 TCL이라고 한다.

# %%
GRANT 권한 부여 REVOKE 권한 삭제

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SYSOPER가 가장 큰 권한!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#사원은 하나의 부서에 포함된다 . 그래서 빨간 줄이 하나

#부서는 여러 사원을 가질수 있다..(그래서 그림에 다리가 많다.!!)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N:N은 어려우니 1:N으로 변경해야 한다.1!!
