# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pymysql

# %% [markdown]
# #### 모든 제품을 크롤링해서 DB에 저장
# - 저장할 DB부터 테이블 생성해서 형식에 맞게 data 변환 후 DB로 insert
#
# 1. DB 연결 코드
# 2. 필요한 DB및 TABLE 생성
# 3. 크롤링
#     - 데이터를 TABLE 형식에 맞게 정제
# 4. inser (데이터 생성)
# 5. commit() 해서 db에 반영
# 6. db 닫기
#
# - db 테이블을 읽어와서 df에 저장

# %%
# 함수 만드는것보다 .py 등 모듈화 시켜서 하자

#db 연결을 호라성화 해주는 함수 구현

def conn(d_name) :
    import pymysql
    host_name = 'localhost'
    host_port = 3306
    username = 'root'
    password = '0000'
    database_name = d_name
    db = pymysql.connect(
        host=host_name,     # MySQL Server Address
        port=host_port,          # MySQL Server Port
        user=username,      # MySQL username
        passwd=password,    # password for MySQL username
        db=database_name,   # Database name
        charset='utf8'
    )
    return db

# %%
db=conn('none')
cursor=db.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-75-ab559aabd1bc> in <module>
# ----> 1 db=conn('none')
#       2 cursor=db.cursor()
#
# <ipython-input-74-4ae4636d60bc> in conn(d_name)
#      10     password = '0000'
#      11     database_name = d_name
# ---> 12     db = pymysql.connect(
#      13         host=host_name,     # MySQL Server Address
#      14         port=host_port,          # MySQL Server Port
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     325             self._sock = None
#     326         else:
# --> 327             self.connect()
#     328
#     329     def _create_ssl_ctx(self, sslp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     586
#     587             self._get_server_information()
# --> 588             self._request_authentication()
#     589
#     590             if self.sql_mode is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     851
#     852         self.write_packet(data)
# --> 853         auth_packet = self._read_packet()
#     854
#     855         # if authentication method isn't accepted the first byte
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'none'")

# %%
sql = 'create database beauty_shop'
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-76-f7c5efef30a6> in <module>
#       1 sql = 'create database beauty_shop'
# ----> 2 cursor.execute(sql)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'beauty_shop'; database exists")

# %%
sql = "show databases"
cursor.execute(sql)
result = cursor.fetchall()
result
# Out:
# (('beauty_shop',),
#  ('beauty_soup',),
#  ('customer_db',),
#  ('dave',),
#  ('ecommerce',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sqldb',),
#  ('student_mgmt',),
#  ('test',))

# %%
sql = "use beauty_shop"
cursor.execute(sql)
# Out:
# 0

# %%
sql = "select database()"
cursor.execute(sql)
result = cursor.fetchone()
result
# Out:
# ('beauty_shop',)

# %%
# table 생성
sql = '''
    CREATE TABLE product (
        PRODUCT_CODE int AUTO_INCREMENT NOT NULL,
        TITLE VARCHAR(200) NOT NULL,
        ORI_PRICE FLOAT,
        DISCOUNT_PRICE FLOAT,
        link VARCHAR(200),
        PRIMARY KEY(PRODUCT_CODE)
    );
'''
cursor.execute(sql)
db.commit()
# 두번 실행시키면 에러난다.~!!!! 1050코드임
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-53-d3e269e07598> in <module>
#      10     );
#      11 '''
# ---> 12 cursor.execute(sql)
#      13 db.commit()
#      14 # 두번 실행시키면 에러난다.~!!!! 1050코드임
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'product' already exists")

# %%
sql = "show tables"
cursor.execute(sql)
result = cursor.fetchall()
result
# Out:
# (('product',),)

# %%
sql = "desc product"
cursor.execute(sql)
result = cursor.fetchall()
result
# Out:
# (('PRODUCT_CODE', 'int(11)', 'NO', 'PRI', None, 'auto_increment'),
#  ('TITLE', 'varchar(200)', 'NO', '', None, ''),
#  ('ORI_PRICE', 'float', 'YES', '', None, ''),
#  ('DISCOUNT_PRICE', 'float', 'YES', '', None, ''),
#  ('link', 'varchar(200)', 'YES', '', None, ''))

# %%
# 보통은 'PRODUCT_CODE','TITLE', 'ORI_PRICE' 정도는 변경안되게 해놓으나 여기서는 'ORI_PRICE'는 변경되게끔한다.

# %% [markdown]
# 2. 크롤링 코드-insert 구문을 추가해서 변경

# %%
# 크롤링 문서 요청해서 응답객체 반환
url="http://jolse.com/category/toners-mists/1019/"
html = urlopen(url)
htmls = html.read()
# print(htmls)
bs_obj = BeautifulSoup(htmls,"html.parser")

# %%
# box안에 들어 있는 1개의 상품에서 정보를 추출해서 dict형태로  반환하는 함수
# 데이터 전처리: 제품명에 ' ' 제거/ 가격 sud 제거/세일가격 없는 경우 처리
def get_product_info(box) :
    p_tag = box.find("p",{"class":"name"})
    # 품목 추출
    span = p_tag.find("span")
    
    # 세부페이지링크 추출
    a = p_tag.find("a")
    sub_link = 'https://jolse.com' + a["href"]
    # 가격 추출 코드
    price_ul = box.find("ul")
    price_span = price_ul.findAll("span")
    
    #데이터 전처리
    title= span.text.replace("'","''") # 아에 공백으로 처리해도됨
    ord_price= price_span[1].text.split(" ")[1] #USD제거
    dis_price= price_span[-1].text.split(" ")[1]
    
    # 세일 가격이 없는 경우
    if dis_price=='':
        dis_price='0.0'
    
    # 최종 data 추출 후 반환
    return{"prd_name":span.text,"price":ord_price,"sale_price":dis_price,"sub_link":sub_link}

# %%
def save_data(prd_info):
    print(prd_info)
    
    #insert 구문
    sql = "INSERT INTO product (title, ori_price, discount_price,link) values('" \
        + prd_info["prd_name"] \
        +"'," \
        + prd_info['price']\
        +"," \
        + prd_info['sale_price']\
        +",'"\
        + prd_info['sub_link']\
        + "')"

#     print(sql)
    curcor.execute(sql)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 전달된 url 페이지에 접근해서 해당페지의 전체 상품 데이터를 추출 한 후 각 상품마다 get_product_info()함수를 호출해서
# 각 상품에대한 추출 정보를 받아옴 - 들어온 각 상품 정보를 리스트에 저장 한 수 해당 반환
def get_page_products(url) :
    url=url
    html = urlopen(url)
    htmls = html.read()
    # print(htmls)
    bs_obj = BeautifulSoup(htmls,"html.parser")

    ## 한 페이지에 모든 상품이 들어있는 ul 태그 추출
    # ul class:prdList grid4
    ul=bs_obj.find("ul",{"class":"prdList grid4"})
    ## 품목 1개를 담고 있는 div 태그 추출
    ## div class:box
    prd_boxes = ul.findAll("div", {"class":"box"}) #1개 페이지의 전체 상품
#     prod_info_list = [get_product_info(box) for box in prd_boxes] # 현재 함수를 통해 접속한 문서(url 인수)의 각 화장품 정보가 
#     # 저장되어 있는 리스트
#     return prod_info_list           ---이부분을 db랑 연결해서insert시켜보자

    # 반환되는 품목 데이터를 db에 insert :함수호출해서 진행
    for box in prd_boxes:
        prd=get_product_info(box)
        print(prd)
        # save_data(prd) # 사용자 정의 함수(생성해야함)

# %%
#last=
int(bs_obj.find("p",{"class":"last"}).find("a")['href'].split("=")[1])
# Out:
# 12

# %% [markdown]
# # main 코드(프로그램 시작점)

# %%
from tqdm import tqdm_notebook # 상태바 표시

#여러 페이지의 화장품 정보를 추출해서 df 에 저장 후 csv에 저장하는 코드
url = "http://jolse.com/category/toners-mists/1019/?page=" #페이지 번호를 제외한 공통 url 문자열

last= int(bs_obj.find("p",{"class":"last"}).find("a")['href'].split("=")[1])
# df_fin = pd.DataFrame()
for i in tqdm_notebook(range(2,last+1)) :
#     url 완성 :page번호를 추가 i 변수 값을 활용
# for i in range(1,2):
    urlfin =url + str(i)
    get_page_products(urlfin)
#     page_product = get_page_products(urlfin)
#     df = pd.DataFrame(page_product) #현재 url로 접속한 페이지의 대해 수집된 제품정보를 df로 생성(한개 페이지 제품)
#     df_fin = pd.concat([df_fin,df],axis=0,ignore_index=True)
# Out:
# <ipython-input-71-5d2fb501bace>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(2,last+1)) :
#   0%|          | 0/11 [00:00<?, ?it/s]
# {'prd_name': 'B_LAB Matcha Hydrating Facial Toner 150ml', 'price': '17.00', 'sale_price': '11.90', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42845&cate_no=1019&display_group=1'}
# {'prd_name': 'META FORET 12PM Calming Toner 150ml', 'price': '13.20', 'sale_price': '11.22', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42825&cate_no=1019&display_group=1'}
# {'prd_name': 'LOOKS&MEII Rich Routine Balance Toner 150ml', 'price': '21.00', 'sale_price': '17.85', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42564&cate_no=1019&display_group=1'}
# {'prd_name': 'LOOKS&MEII Fresh Routine Balance Toner 150ml', 'price': '21.00', 'sale_price': '17.85', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42547&cate_no=1019&display_group=1'}
# {'prd_name': 'MISSHA Time Revolution Best Seller Special Set', 'price': '54.99', 'sale_price': '46.74', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42310&cate_no=1019&display_group=1'}
# {'prd_name': 'Dr.Ceuracle Pro Balance Biotics Toner 300ml', 'price': '30.00', 'sale_price': '25.50', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42292&cate_no=1019&display_group=1'}
# {'prd_name': 'Dr.Ceuracle Cica Regen 92 Toner 120ml', 'price': '25.00', 'sale_price': '21.25', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42287&cate_no=1019&display_group=1'}
# {'prd_name': 'MANYO FACTORY Bifida Cica Herb Toner 210ml', 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42278&cate_no=1019&display_group=1'}
# {'prd_name': 'MANYO FACTORY Galac Whitening Vita Toner 210ml', 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42276&cate_no=1019&display_group=1'}
# {'prd_name': 'SOME BY MI Propolis B5 Glow Barrier Calming Toner 150ml', 'price': '22.00', 'sale_price': '18.70', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42205&cate_no=1019&display_group=1'}
# {'prd_name': 'banila co. Dear Hydration Toner 280ml', 'price': '24.00', 'sale_price': '16.80', 'sub_link': 'https://jolse.com/product/detail.html?product_no=42194&cate_no=1019&display_group=1'}
# {'prd_name': 'SKIN1004 Madagascar Centella Tone Brightening Boosting Toner 210ml', 'price': '24.00', 'sale_price': '16.80', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41720&cate_no=1019&display_group=1'}
# {'prd_name': 'Beauty of Joseon Green Plum + AHA Bubble Toner 150ml', 'price': '22.00', 'sale_price': '14.63', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41718&cate_no=1019&display_group=1'}
# {'prd_name': 'Pyunkang Yul Calming Deep Moisture Toner 150ml', 'price': '15.00', 'sale_price': '12.75', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41712&cate_no=1019&display_group=1'}
# {'prd_name': 'innisfree Forest For Men Premium Skin Care Duo Set', 'price': '58.00', 'sale_price': '40.60', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41467&cate_no=1019&display_group=1'}
# {'prd_name': 'innisfree Green Tea Balancing Skin Care Set EX', 'price': '42.00', 'sale_price': '29.40', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41466&cate_no=1019&display_group=1'}
# {'prd_name': 'innisfree Black Tea Youth Enhancing Skin 150ml', 'price': '28.00', 'sale_price': '19.60', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41450&cate_no=1019&display_group=1'}
# {'prd_name': 'Haruharu WONDER Black Rice Hyaluronic Toner 150ml (Fragrance Free)', 'price': '22.00', 'sale_price': '18.70', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41258&cate_no=1019&display_group=1'}
# {'prd_name': 'Dr.G Red Blemish Clear Soothing Toner 200ml', 'price': '23.00', 'sale_price': '16.10', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41224&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Hydration Trio Set', 'price': '82.00', 'sale_price': '57.17', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41203&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Essential Mist Sense Of Balance 35ml', 'price': '21.00', 'sale_price': '14.64', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41200&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Oil Mist Sense Of Balance 35ml', 'price': '21.00', 'sale_price': '14.64', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41197&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Antioxidant Trio Set', 'price': '82.00', 'sale_price': '57.17', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41196&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Extra Moisture Trio Set', 'price': '84.00', 'sale_price': '58.56', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41194&cate_no=1019&display_group=1'}
# {'prd_name': 'Huxley Brightening Trio Set', 'price': '85.00', 'sale_price': '59.26', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41191&cate_no=1019&display_group=1'}
# {'prd_name': 'O HUI Extreme White 2pcs Special Set', 'price': '100.00', 'sale_price': '85.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41173&cate_no=1019&display_group=1'}
# {'prd_name': 'su:m37 Waterfull Special Set', 'price': '110.00', 'sale_price': '87.89', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41172&cate_no=1019&display_group=1'}
# {'prd_name': 'AXIS-Y The Mini Glow Set', 'price': '9.90', 'sale_price': '8.41', 'sub_link': 'https://jolse.com/product/detail.html?product_no=41165&cate_no=1019&display_group=1'}
# {'prd_name': 'AXIS-Y My Self Care Set Limited Edition', 'price': '32.00', 'sale_price': '27.20', 'sub_link': 'https://jolse.com/product/detail.html?product_no=
 'sub_link': 'https://jolse.com/product/detail.html?product_no=40635&cate_no=1019&display_group=1'}
# {'prd_name': 'primera Organience Water 180ml', 'price': '35.00', 'sale_price': '29.75', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40633&cate_no=1019&display_group=1'}
# {'prd_name': 'Yehwadam Hwansaenggo Rejuvenating Radiance Toner 160ml', 'price': '35.00', 'sale_price': '26.21', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40591&cate_no=1019&display_group=1'}
# {'prd_name': 'Yehwadam Hwansaenggo Ultimate Rejuvenating Toner 160ml', 'price': '35.00', 'sale_price': '26.21', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40590&cate_no=1019&display_group=1'}
# {'prd_name': 'Yehwadam Artemisia Soothing Moisturizing Toner 180ml', 'price': '26.00', 'sale_price': '19.47', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40585&cate_no=1019&display_group=1'}
# {'prd_name': 'Yehwadam Plum Flower Revitalizing Toner 160ml', 'price': '28.00', 'sale_price': '20.97', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40581&cate_no=1019&display_group=1'}
# {'prd_name': 'ETUDE HOUSE AC Clean Up Toner 200ml', 'price': '18.57', 'sale_price': '15.78', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40385&cate_no=1019&display_group=1'}
# {'prd_name': 'SOME BY MI AHA BHA PHA 30 Days Miracle Travel Kit', 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40369&cate_no=1019&display_group=1'}
# {'prd_name': 'su:m37 sum37 Time energy Resetting Toner 170ml', 'price': '45.00', 'sale_price': '35.95', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40244&cate_no=1019&display_group=1'}
# {'prd_name': 'VILLAGE 11 FACTORY Blue Chamomile Toner 250ml', 'price': '18.00', 'sale_price': '15.30', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40189&cate_no=1019&display_group=1'}
# {'prd_name': 'Aromatica Tea Tree Balancing Toner 200ml (Renewal)', 'price': '35.00', 'sale_price': '29.75', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40188&cate_no=1019&display_group=1'}
# {'prd_name': 'Real Barrier Extreme Essence Toner 190ml (Renewal)', 'price': '30.00', 'sale_price': '25.50', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40186&cate_no=1019&display_group=1'}
# {'prd_name': 'celimax Dual Barrier Creamy Toner 150ml', 'price': '24.00', 'sale_price': '20.40', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40163&cate_no=1019&display_group=1'}
# {'prd_name': 'The FACE Shop The Gentle For Men Anti-Aging Toner 140ml', 'price': '29.16', 'sale_price': '20.38', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40127&cate_no=1019&display_group=1'}
# {'prd_name': 'Nature Republic Argan Homme Skin 130ml', 'price': '24.16', 'sale_price': '20.54', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40122&cate_no=1019&display_group=1'}
# {'prd_name': 'Cos De BAHA Peptide Toner 200ml', 'price': '17.00', 'sale_price': '14.45', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40112&cate_no=1019&display_group=1'}
# {'prd_name': 'Cos De BAHA Niacinamide Toner 200ml', 'price': '18.00', 'sale_price': '15.30', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40102&cate_no=1019&display_group=1'}
# {'prd_name': 'Cos De BAHA AHA/BHA GS Toner 200ml', 'price': '17.00', 'sale_price': '14.45', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40101&cate_no=1019&display_group=1'}
# {'prd_name': 'Cos De BAHA Centella Facial Toner 200ml', 'price': '16.45', 'sale_price': '13.98', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40098&cate_no=1019&display_group=1'}
# {'prd_name': 'Cos De BAHA Salicylic Acid 2% Liquid 120ml', 'price': '14.99', 'sale_price': '12.74', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40093&cate_no=1019&display_group=1'}
# {'prd_name': 'COSRX Poreless Pad 70pcs', 'price': '25.00', 'sale_price': '21.25', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40051&cate_no=1019&display_group=1'}
# {'prd_name': 'COSRX Pure Fit Cica Pad 90pcs', 'price': '27.00', 'sale_price': '22.95', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40049&cate_no=1019&display_group=1'}
# {'prd_name': 'COSRX Pure Fit Cica Powder 10g (renewal)', 'price': '18.00', 'sale_price': '15.30', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40047&cate_no=1019&display_group=1'}
# {'prd_name': 'HOLIKA HOLIKA Honey Royalactin Serum Mist 120ml', 'price': '29.16', 'sale_price': '24.79', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40037&cate_no=1019&display_group=1'}
# {'prd_name': 'HOLIKA HOLIKA Gold Kiwi Vita C+ Brightening Toner 150ml', 'price': '34.16', 'sale_price': '29.04', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40033&cate_no=1019&display_group=1'}
# {'prd_name': 'HOLIKA HOLIKA Premier Collagen Toner 125ml', 'price': '32.16', 'sale_price': '27.34', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40025&cate_no=1019&display_group=1'}
# {'prd_name': 'OGANA CELL Sky Blue Toner 130ml', 'price': '42.00', 'sale_price': '35.70', 'sub_link': 'https://jolse.com/product/detail.html?product_no=40011&cate_no=1019&display_group=1'}
# {'prd_name': 'O HUI Age Recovery Special Set', 'price': '128.00', 'sale_price': '108.80', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39984&cate_no=1019&display_group=1'}
# {'prd_name': 'O HUI Miracle Moisture Special Set', 'price': '90.00', 'sale_price': '76.50', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39981&cate_no=1019&display_group=1'}
# {'prd_name': 'su:m37 Waterfull Special Set (renewal)', 'price': '135.00', 'sale_price': '94.36', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39980&cate_no=1019&display_group=1'}
# {'prd_name': 'su:m37 Time Energy Special Set (renewal)', 'price': '125.00', 'sale_price': '87.37', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39979&cate_no=1019&display_group=1'}
# {'prd_name': 'OGANA CELL Peptide Concentrating Heaven Water 120ml', 'price': '62.00', 'sale_price': '52.70', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39967&cate_no=1019&display_group=1'}
# {'prd_name': 'Mamonde Ceramide Skin Softener 200ml', 'price': '27.16', 'sale_price': '23.09', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39957&cate_no=1019&display_group=1'}
# {'prd_name': 'Mamonde Centella Trouble Toner 250ml', 'price': '25.16', 'sale_price': '21.39', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39954&cate_no=1019&display_group=1'}
# {'prd_name': 'The History of Whoo Cheongidan Goon Hwa Yang Skin 150ml', 'price': '75.00', 'sale_price': '63.75', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39921&cate_no=1019&display_group=1'}
# {'prd_name': 'TIAM AC Fighting PHA 12 Purifying Liquid 80ml', 'price': '23.00', 'sale_price': '19.55', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39900&cate_no=1019&display_group=1'}
# {'prd_name': 'THANK YOU FARMER Rice Pure Essential Toner 200ml', 'price': '28.00', 'sale_price': '23.80', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39889&cate_no=1019&display_group=1'}
# {'prd_name': 'daymellow Aqualron Watery Toner 300ml', 'price': '21.00', 'sale_price': '12.60', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39858&cate_no=1019&display_group=1'}
# {'prd_name': 'daymellow Bluemarin Purity Toner 200ml', 'price': '26.00', 'sale_price': '15.60', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39833&cate_no=1019&display_group=1'}
# {'prd_name': 'goodal Houttuynia Cordata Calming Toner Pad 70pcs', 'price': '28.57', 'sale_price': '24.28', 'sub_link': 'https://jolse.com/product/detail.html?product_no=39413&cate_no=1019&display_group=1'}
# {'prd_name': 'LANEIGE Perfect Renew Youth Refiner 120ml', 'price': '47.16', 'sale_price': '40.09', 'sub_link': 'https://jolse.com/product/detail.html?product_no=
 'sub_link': 'https://jolse.com/product/detail.html?product_no=28851&cate_no=1019&display_group=1'}
# {'prd_name': 'isoi Acni Dr. Trial Kit', 'price': '20.00', 'sale_price': '17.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28850&cate_no=1019&display_group=1'}
# {'prd_name': 'Real Barrier Cicarelief Toner 190ml', 'price': '31.20', 'sale_price': '26.52', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28821&cate_no=1019&display_group=1'}
# {'prd_name': 'Real Barrier Control-T Toner 190ml', 'price': '28.80', 'sale_price': '24.48', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28816&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC The Simple Calming Toner 145ml', 'price': '18.00', 'sale_price': '15.30', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28809&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC Snail Matrix Skin 150ml', 'price': '20.00', 'sale_price': '17.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28803&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC Cicanoid Toner 150ml', 'price': '20.00', 'sale_price': '17.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28786&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC First Treatment Mist 120ml', 'price': '17.00', 'sale_price': '14.45', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28782&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC Hyaluronic Acid First Skin Essence 500ml', 'price': '32.00', 'sale_price': '27.20', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28771&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC Hyaluronic Acid Ampoule Skin 150ml', 'price': '18.00', 'sale_price': '15.30', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28768&cate_no=1019&display_group=1'}
# {'prd_name': 'SCINIC Super Moist Essence Water 200ml', 'price': '20.00', 'sale_price': '17.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28756&cate_no=1019&display_group=1'}
# {'prd_name': 'SKIN1004 Madagascar Centella Toning Toner 210ml', 'price': '20.00', 'sale_price': '14.00', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28744&cate_no=1019&display_group=1'}
# {'prd_name': 'VONIN The Character Skin & Emulsion Set', 'price': '35.70', 'sale_price': '30.34', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28719&cate_no=1019&display_group=1'}
# {'prd_name': 'VONIN Majesta Recovery Fluid 150ml', 'price': '57.13', 'sale_price': '48.56', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28716&cate_no=1019&display_group=1'}
# {'prd_name': 'VONIN The Style Standard Toner & Emulsion Set', 'price': '42.84', 'sale_price': '36.41', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28712&cate_no=1019&display_group=1'}
# {'prd_name': 'VONIN The Style Standard Toner 135ml', 'price': '22.13', 'sale_price': '18.81', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28708&cate_no=1019&display_group=1'}
# {'prd_name': 'Derma Lift Milderm Hyaluronic Toner Special Set', 'price': '35.75', 'sale_price': '30.39', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28673&cate_no=1019&display_group=1'}
# {'prd_name': 'Derma Lift Intensiderm Rich Toner Special Set', 'price': '41.47', 'sale_price': '35.25', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28669&cate_no=1019&display_group=1'}
# {'prd_name': 'SOME BY MI Yuja Niacin 30 Days Brightening Starter Kit', 'price': '28.00', 'sale_price': '23.80', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28389&cate_no=1019&display_group=1'}
# {'prd_name': 'SOME BY MI Yuja Niacin Brightening Toner 150ml', 'price': '24.00', 'sale_price': '20.40', 'sub_link': 'https://jolse.com/product/detail.html?product_no=28380&cate_no=1019&display_group=1'}
# {'prd_name': 'CAREZONE Derma Milk-Hyaluronic Cream Skin Set', 'price': '27.13', 'sale_price': '23.06', 'sub_link': 'https://jolse.com/product/detail.html?product_no=
# {'prd_name': 'ETUDE HOUSE Belle Dress Shower Cologne 100ml', 'price': '12.13', 'sale_price': '10.31', 'sub_link': 'https://jolse.com/product/detail.html?product_no=5422&cate_no=1019&display_group=1'}
# {'prd_name': 'HOLIKA HOLIKA Prime Youth Black Snail Repair Toner 160ml', 'price': '30.16', 'sale_price': '25.64', 'sub_link': 'https://jolse.com/product/detail.html?product_no=5205&cate_no=1019&display_group=1'}
# {'prd_name': 'MISSHA Perfumed shower Cologne 105ml', 'price': '10.16', 'sale_price': '8.64', 'sub_link': 'https://jolse.com/product/detail.html?product_no=4143&cate_no=1019&display_group=1'}
# {'prd_name': 'COSRX AHA/BHA CLARIFYING TREATMENT TONER 150ml', 'price': '17.25', 'sale_price': '14.66', 'sub_link': 'https://jolse.com/product/detail.html?product_no=3396&cate_no=1019&display_group=1'}
# {'prd_name': 'COSRX CENTELLA WATER ALCHOL-FREE TONER 150ml', 'price': '17.25', 'sale_price': '14.66', 'sub_link': 'https://jolse.com/product/detail.html?product_no=3367&cate_no=1019&display_group=1'}
# {'prd_name': "It's skin Collagen Nutrition Toner 150ml", 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=2356&cate_no=1019&display_group=1'}
# {'prd_name': "It's skin Aloe Relaxing Toner 150ml", 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=2354&cate_no=1019&display_group=1'}
# {'prd_name': "It's skin Hyaluronic Acid Moisture Toner 150ml", 'price': '19.00', 'sale_price': '16.15', 'sub_link': 'https://jolse.com/product/detail.html?product_no=2351&cate_no=1019&display_group=1'}
# {'prd_name': 'Ciracle Base Toner pH5.6 105.5ml', 'price': '23.48', 'sale_price': '19.96', 'sub_link': 'https://jolse.com/product/detail.html?product_no=1160&cate_no=1019&display_group=1'}
# {'prd_name': '[Ciracle] Anti-Blemish Toner 105.5ml', 'price': '22.25', 'sale_price': '18.91', 'sub_link': 'https://jolse.com/product/detail.html?product_no=1158&cate_no=1019&display_group=1'}
# {'prd_name': 'Ciracle Pore Control Tightening Toner 105.5ml', 'price': '21.48', 'sale_price': '18.26', 'sub_link': 'https://jolse.com/product/detail.html?product_no=1156&cate_no=1019&display_group=1'}

# %%
db.commit()

# %%
sql = "select * from product"
cursor.execute(sql)
result = cursor.fetchall()
result
# Out:
# ()

# %% [markdown]
# #### 데이터 전처리시 반영했던거 정리
# ![image.png](attachment:image.png)

# %%
db.close()

# %% [markdown]
# # db 테이블에 저장된 데이터 df로 가져오기

# %%
db=conn('beauty_shop')

# %%
sql = "select * from product"
df = pd.read_sql(sql,db)
df
# Out:
# Empty DataFrame
# Columns: [PRODUCT_CODE, TITLE, ORI_PRICE, DISCOUNT_PRICE, link]
# Index: []

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 추가 설명
#            ---- 제품명에서 ' 기호 제거
#            ---- 가격에서 USD 제거
#            ---- 세일가격이 없는 경우에 대한 처리

# %%
df_fin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-6bc8d62787b5> in <module>
# ----> 1 df_fin
#
# NameError: name 'df_fin' is not defined

# %%
df_fin.to_csv('data\prod_All2.csv')
